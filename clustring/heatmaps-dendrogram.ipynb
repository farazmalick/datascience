# %%
import pandas as pd
import seaborn as sb

# %%
data=pd.read_csv("3.12. Segmentation_1.csv")
data
# Out:
#     Satisfaction  Loyalty
# 0              4    -1.33
# 1              6    -0.28
# 2              5    -0.99
# 3              7    -0.29
# 4              4     1.06
# 5              1    -1.66
# 6             10    -0.97
# 7              8    -0.32
# 8              8     1.02
# 9              8     0.68
# 10            10    -0.34
# 11             5     0.39
# 12             5    -1.69
# 13             2     0.67
# 14             7     0.27
# 15             9     1.36
# 16             8     1.38
# 17             7     1.36
# 18             7    -0.34
# 19             9     0.67
# 20            10     1.18
# 21             3    -1.69
# 22             4     1.04
# 23             3    -0.96
# 24             6     1.03
# 25             9    -0.99
# 26            10     0.37
# 27             9     0.03
# 28             3    -1.36
# 29             5     0.73

# %%
sb.clustermap(data)

# %%
data2=pd.read_csv("3.01. Country clusters.csv",index_col='Country')
data2
# Out:
#            Latitude  Longitude Language
# Country
# USA           44.97    -103.77  English
# Canada        62.40     -96.80  English
# France        46.75       2.40   French
# UK            54.01      -2.53  English
# Germany       51.15      10.40   German
# Australia    -25.45     133.11  English

# %%
drop_data=data2.copy()
drop_data=drop_data.drop([])
